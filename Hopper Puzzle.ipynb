# %% [markdown]
# # Hopper Puzzle

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline

# %%
df = pd.read_csv('puzzle.csv', header=None)
df.columns = ['A','B']
df.head(5)
# Out:
#          A         B
# 0  0.39715  2.113629
# 1  0.39715  2.113629
# 2  0.39715  2.113629
# 3  0.39715  2.113629
# 4  0.39715  2.113629

# %% [markdown]
# ### No null rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1024 entries, 0 to 1023
# Data columns (total 2 columns):
# A    1024 non-null float64
# B    1024 non-null float64
# dtypes: float64(2)
# memory usage: 16.1 KB

# %% [markdown]
# ## Checking correlation

# %%
sns.pairplot(df,aspect=2,size=10,vars=["A", "B"])

# %% [markdown]
# ### Very interesting results as A vs B is giving us a sort of a map like form

# %%
sns.lmplot(x="B", y="A", data=df,fit_reg=False, size=10, aspect=2)
